# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import os

# %% [markdown]
# # Set global data path

# %%
# path where the csv files are saved
data_folder = '/Users/luisalcala/Desktop/redbull/data'

# %% [markdown]
# # Load raw data

# %%
# dictionaty to store the standings
standings_files = {}

# for each file in the path (we only have csv files)
for file_name in os.listdir(data_folder):
    print(file_name)
    if file_name[0] == 's':
        # read csv with particular header
        df = pd.read_csv(os.path.join(data_folder, file_name), encoding='ISO-8859-1')
        # Add the DataFrame to the dictionary with key = file name
        standings_files[os.path.splitext(file_name)[0]] = df
    else:
        # read transfer csv
        transfers_df = pd.read_csv(os.path.join(data_folder, file_name), index_col=[0])
# Out:
# standings-bundesliga-19-20.csv
# standings-bundesliga-21-22.csv
# transfers-bundesliga.csv
# standings-bundesliga-23-24.csv
# standings-bundesliga-22-23.csv
# standings-bundesliga-20-21.csv

# %%
len(standings_files)
# Out:
# 5

# %%
transfers_df.head()
# Out:
#    transfer_id transfer_datetime       transfer_type season  season_id  \
# 0      2518704        2019-07-01  free loan transfer  19/20       2019
# 1      2472611        2019-07-01       free transfer  19/20       2019
# 2      2512548        2019-07-01  free loan transfer  19/20       2019
# 3      2507880        2019-07-01  free loan transfer  19/20       2019
# 4      2491956        2019-07-01                 NaN  19/20       2019
#
#    player_id       player_name  player_age_at_transfer  transfer_fee_euro  \
# 0     314245    Emmanuel Iyoha                    21.0                NaN
# 1     153634    Marcel Hilßner                    24.0                0.0
# 2     195676        Ole Käuper                    22.0                NaN
# 3     236986    Thore Jacobsen                    22.0                NaN
# 4      31652  Fabian Schönheim                    32.0                NaN
#
#    transfer_fee_million  ...     to.club_name  to.competition_id  \
# 0                   NaN  ...    Holstein Kiel                 L2
# 1                   0.0  ...     SC Paderborn                 L1
# 2                   NaN  ...  Carl Zeiss Jena                 L3
# 3                   NaN  ...        Magdeburg                 L3
# 4                   NaN  ...     Without Club                NaN
#
#    to.competition_name date_of_birth_datetime            citizenship  \
# 0        2. Bundesliga             1997-10-11  ['Germany' 'Nigeria']
# 1           Bundesliga             1995-01-30            ['Germany']
# 2              3. Liga             1997-01-09            ['Germany']
# 3              3. Liga             1997-04-19            ['Germany']
# 4                  NaN             1987-02-14            ['Germany']
#
#         position.main                      position.other height_cm   foot  \
# 0           Left-Back        ['Right-Back' 'Left Winger']     191.0  right
# 1  Attacking Midfield      ['Right Winger' 'Left Winger']     183.0   left
# 2  Defensive Midfield                ['Central Midfield']     187.0   left
# 3  Defensive Midfield    ['Central Midfield' 'Left-Back']     182.0   left
# 4         Centre-Back  ['Left-Back' 'Defensive Midfield']       NaN    NaN
#
#                    updated_at
# 0  2024-02-25T02:16:17.122733
# 1  2024-02-24T10:13:57.036699
# 2  2024-02-24T10:13:48.186890
# 3  2024-02-24T10:13:43.016587
# 4  2024-02-24T23:49:23.092466
#
# [5 rows x 27 columns]

# %%
standings_files['standings-bundesliga-19-20'].head()
# Out:
#   Unnamed: 0                Unnamed: 1 Home Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN                       NaN    P          W          D          L
# 1          C             Bayern Munich   17         13          2          2
# 2          2         Borussia Dortmund   17         11          3          3
# 3          3                RB Leipzig   17          7          8          2
# 4          4  Borussia Mönchengladbach   17         12          2          3
#
#   Away Unnamed: 7 Unnamed: 8 Unnamed: 9 Total Unnamed: 11 Unnamed: 12  \
# 0    P          W          D          L     P           W           D
# 1   17         13          2          2    34          26           4
# 2   17         10          3          4    34          21           6
# 3   17         11          4          2    34          18          12
# 4   17          8          3          6    34          20           5
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17
# 0           L           F           A         +/-         Pts
# 1           4         100          32         +68          82
# 2           7          84          41         +43          69
# 3           4          81          37         +44          66
# 4           9          66          40         +26          65

# %% [markdown]
# # Standings

# %% [markdown]
# ## Process column names

# %%
# as all stadings files have the same structure, we can set the column names we'd like
column_names = [
    'final_standing', 'team_name', 
    'home_points', 'home_wins', 'home_draws', 'home_losses', 
    'away_points', 'away_wins', 'away_draws', 'away_losses', 
    'total_points', 'total_wins', 'total_draws', 'total_losses',
    'goals_in_favor', 'goals_against', 'goals_balance', 'points'
    ]

# change column names for the standings files
for file_name, df in standings_files.items():
    df.columns = column_names
    df.drop(index=df.index[0], inplace=True)
    df.reset_index(drop=True, inplace=True)

# %%
standings_files['standings-bundesliga-19-20'].head(18)
# Out:
#    final_standing                 team_name home_points home_wins home_draws  \
# 0               C             Bayern Munich          17        13          2
# 1               2         Borussia Dortmund          17        11          3
# 2               3                RB Leipzig          17         7          8
# 3               4  Borussia Mönchengladbach          17        12          2
# 4               5       Bayer 04 Leverkusen          17         9          4
# 5               6           1899 Hoffenheim          17         7          1
# 6               7             VfL Wolfsburg          17         4          7
# 7               8               SC Freiburg          17         9          2
# 8               9       Eintracht Frankfurt          17         8          4
# 9              10             Hertha Berlin          17         6          3
# 10             11        1. FC Union Berlin          17         8          3
# 11             12             FC Schalke 04          17         5          7
# 12             13                  Mainz 05          17         5          2
# 13             14                1. FC Köln          17         6          4
# 14             15               FC Augsburg          17         5          5
# 15             16             Werder Bremen          17         2          3
# 16              R        Fortuna Düsseldorf          17         4          6
# 17              R           SC Paderborn 07          17         2          2
#
#    home_losses away_points away_wins away_draws away_losses total_points  \
# 0            2          17        13          2           2           34
# 1            3          17        10          3           4           34
# 2            2          17        11          4           2           34
# 3            3          17         8          3           6           34
# 4            4          17        10          2           5           34
# 5            9          17         8          6           3           34
# 6            6          17         9          3           5           34
# 7            6          17         4          7           6           34
# 8            5          17         5          2          10           34
# 9            8          17         5          5           7           34
# 10           6          17         4          2          11           34
# 11           5          17         4          5           8           34
# 12          10          17         6          2           9           34
# 13           7          17         4          2          11           34
# 14           7          17         4          4           9           34
# 15          12          17         6          4           7           34
# 16           7          17         2          6           9           34
# 17          13          17         2          6           9           34
#
#    total_wins total_draws total_losses goals_in_favor goals_against  \
# 0          26           4            4            100            32
# 1          21           6            7             84            41
# 2          18          12            4             81            37
# 3          20           5            9             66            40
# 4          19           6            9             61            44
# 5          15           7           12             53            53
# 6          13          10           11             48            46
# 7          13           9           12             48            47
# 8          13           6           15             59            60
# 9          11           8           15             48            59
# 10         12           5           17             41            58
# 11          9          12           13             38            58
# 12         11           4           19             44            65
# 13         10           6           18             51            69
# 14          9           9           16             45            63
# 15          8           7           19             42            69
# 16          6          12           16             36            67
# 17          4           8           22             37            74
#
#    goals_balance points
# 0            +68     82
# 1            +43     69
# 2            +44     66
# 3            +26     65
# 4            +17     63
# 5              0     52
# 6             +2     49
# 7             +1     48
# 8             -1     45
# 9            -11     41
# 10           -17     41
# 11           -20     39
# 12           -21     37
# 13           -18     36
# 14           -18     36
# 15           -27     31
# 16           -31     30
# 17           -37     20

# %%
standings_files['standings-bundesliga-20-21'].head(18)
# Out:
#    final_standing                 team_name home_points home_wins home_draws  \
# 0               C             Bayern Munich          17        13          4
# 1               2                RB Leipzig          17        11          4
# 2               3         Borussia Dortmund          17        11          2
# 3               4             VfL Wolfsburg          17        10          4
# 4               5       Eintracht Frankfurt          17        10          7
# 5               6       Bayer 04 Leverkusen          17         8          5
# 6               7        1. FC Union Berlin          17         8          8
# 7               8  Borussia Mönchengladbach          17         8          4
# 8               9             VfB Stuttgart          17         5          6
# 9              10               SC Freiburg          17         7          6
# 10             11           1899 Hoffenheim          17         8          3
# 11             12                  Mainz 05          17         4          4
# 12             13               FC Augsburg          17         6          4
# 13             14             Hertha Berlin          17         5          5
# 14             15         Arminia Bielefeld          17         6          2
# 15             16                1. FC Köln          17         3          5
# 16             17             Werder Bremen          17         3          5
# 17             18             FC Schalke 04          17         3          3
#
#    home_losses away_points away_wins away_draws away_losses total_points  \
# 0            0          17        11          2           4           34
# 1            2          17         8          4           5           34
# 2            4          17         9          2           6           34
# 3            3          17         7          6           4           34
# 4            0          17         6          5           6           34
# 5            4          17         6          5           6           34
# 6            1          17         4          6           7           34
# 7            5          17         5          6           6           34
# 8            6          17         7          3           7           34
# 9            4          17         5          3           9           34
# 10           6          17         3          7           7           34
# 11           9          17         6          5           6           34
# 12           7          17         4          2          11           34
# 13           7          17         3          6           8           34
# 14           9          17         3          6           8           34
# 15           9          17         5          4           8           34
# 16           9          17         4          5           8           34
# 17          11          17         0          4          13           34
#
#    total_wins total_draws total_losses goals_in_favor goals_against  \
# 0          24           6            4             99            44
# 1          19           8            7             60            32
# 2          20           4           10             75            46
# 3          17          10            7             61            37
# 4          16          12            6             69            53
# 5          14          10           10             53            39
# 6          12          14            8             50            43
# 7          13          10           11             64            56
# 8          12           9           13             56            55
# 9          12           9           13             52            52
# 10         11          10           13             52            54
# 11         10           9           15             39            56
# 12         10           6           18             36            54
# 13          8          11           15             41            52
# 14          9           8           17             26            52
# 15          8           9           17             34            60
# 16          7          10           17             36            57
# 17          3           7           24             25            86
#
#    goals_balance points
# 0            +55     78
# 1            +28     65
# 2            +29     64
# 3            +24     61
# 4            +16     60
# 5            +14     52
# 6             +7     50
# 7             +8     49
# 8             +1     45
# 9              0     45
# 10            -2     43
# 11           -17     39
# 12           -18     36
# 13           -11     35
# 14           -26     35
# 15           -26     33
# 16           -21     31
# 17           -61     16

# %% [markdown]
# ## Change C and R values per corresponding numerical standing

# %% [markdown]
# In some files, the Champions and the Relegation teams are marked as C and R respectively, let's change that to 1 and 17/18 respectively. To do that, we just set the final standing as the index value +1 as we know the first is going to be the champion and the last two relegated (does not change over the seasons for now).

# %%
for file_name, df in standings_files.items():
    df['final_standing'] = df.index + 1

# %%
standings_files['standings-bundesliga-19-20'].head(18)
# Out:
#     final_standing                 team_name home_points home_wins home_draws  \
# 0                1             Bayern Munich          17        13          2
# 1                2         Borussia Dortmund          17        11          3
# 2                3                RB Leipzig          17         7          8
# 3                4  Borussia Mönchengladbach          17        12          2
# 4                5       Bayer 04 Leverkusen          17         9          4
# 5                6           1899 Hoffenheim          17         7          1
# 6                7             VfL Wolfsburg          17         4          7
# 7                8               SC Freiburg          17         9          2
# 8                9       Eintracht Frankfurt          17         8          4
# 9               10             Hertha Berlin          17         6          3
# 10              11        1. FC Union Berlin          17         8          3
# 11              12             FC Schalke 04          17         5          7
# 12              13                  Mainz 05          17         5          2
# 13              14                1. FC Köln          17         6          4
# 14              15               FC Augsburg          17         5          5
# 15              16             Werder Bremen          17         2          3
# 16              17        Fortuna Düsseldorf          17         4          6
# 17              18           SC Paderborn 07          17         2          2
#
#    home_losses away_points away_wins away_draws away_losses total_points  \
# 0            2          17        13          2           2           34
# 1            3          17        10          3           4           34
# 2            2          17        11          4           2           34
# 3            3          17         8          3           6           34
# 4            4          17        10          2           5           34
# 5            9          17         8          6           3           34
# 6            6          17         9          3           5           34
# 7            6          17         4          7           6           34
# 8            5          17         5          2          10           34
# 9            8          17         5          5           7           34
# 10           6          17         4          2          11           34
# 11           5          17         4          5           8           34
# 12          10          17         6          2           9           34
# 13           7          17         4          2          11           34
# 14           7          17         4          4           9           34
# 15          12          17         6          4           7           34
# 16           7          17         2          6           9           34
# 17          13          17         2          6           9           34
#
#    total_wins total_draws total_losses goals_in_favor goals_against  \
# 0          26           4            4            100            32
# 1          21           6            7             84            41
# 2          18          12            4             81            37
# 3          20           5            9             66            40
# 4          19           6            9             61            44
# 5          15           7           12             53            53
# 6          13          10           11             48            46
# 7          13           9           12             48            47
# 8          13           6           15             59            60
# 9          11           8           15             48            59
# 10         12           5           17             41            58
# 11          9          12           13             38            58
# 12         11           4           19             44            65
# 13         10           6           18             51            69
# 14          9           9           16             45            63
# 15          8           7           19             42            69
# 16          6          12           16             36            67
# 17          4           8           22             37            74
#
#    goals_balance points
# 0            +68     82
# 1            +43     69
# 2            +44     66
# 3            +26     65
# 4            +17     63
# 5              0     52
# 6             +2     49
# 7             +1     48
# 8             -1     45
# 9            -11     41
# 10           -17     41
# 11           -20     39
# 12           -21     37
# 13           -18     36
# 14           -18     36
# 15           -27     31
# 16           -31     30
# 17           -37     20

# %%
standings_files['standings-bundesliga-20-21'].head(18)
# Out:
#     final_standing                 team_name home_points home_wins home_draws  \
# 0                1             Bayern Munich          17        13          4
# 1                2                RB Leipzig          17        11          4
# 2                3         Borussia Dortmund          17        11          2
# 3                4             VfL Wolfsburg          17        10          4
# 4                5       Eintracht Frankfurt          17        10          7
# 5                6       Bayer 04 Leverkusen          17         8          5
# 6                7        1. FC Union Berlin          17         8          8
# 7                8  Borussia Mönchengladbach          17         8          4
# 8                9             VfB Stuttgart          17         5          6
# 9               10               SC Freiburg          17         7          6
# 10              11           1899 Hoffenheim          17         8          3
# 11              12                  Mainz 05          17         4          4
# 12              13               FC Augsburg          17         6          4
# 13              14             Hertha Berlin          17         5          5
# 14              15         Arminia Bielefeld          17         6          2
# 15              16                1. FC Köln          17         3          5
# 16              17             Werder Bremen          17         3          5
# 17              18             FC Schalke 04          17         3          3
#
#    home_losses away_points away_wins away_draws away_losses total_points  \
# 0            0          17        11          2           4           34
# 1            2          17         8          4           5           34
# 2            4          17         9          2           6           34
# 3            3          17         7          6           4           34
# 4            0          17         6          5           6           34
# 5            4          17         6          5           6           34
# 6            1          17         4          6           7           34
# 7            5          17         5          6           6           34
# 8            6          17         7          3           7           34
# 9            4          17         5          3           9           34
# 10           6          17         3          7           7           34
# 11           9          17         6          5           6           34
# 12           7          17         4          2          11           34
# 13           7          17         3          6           8           34
# 14           9          17         3          6           8           34
# 15           9          17         5          4           8           34
# 16           9          17         4          5           8           34
# 17          11          17         0          4          13           34
#
#    total_wins total_draws total_losses goals_in_favor goals_against  \
# 0          24           6            4             99            44
# 1          19           8            7             60            32
# 2          20           4           10             75            46
# 3          17          10            7             61            37
# 4          16          12            6             69            53
# 5          14          10           10             53            39
# 6          12          14            8             50            43
# 7          13          10           11             64            56
# 8          12           9           13             56            55
# 9          12           9           13             52            52
# 10         11          10           13             52            54
# 11         10           9           15             39            56
# 12         10           6           18             36            54
# 13          8          11           15             41            52
# 14          9           8           17             26            52
# 15          8           9           17             34            60
# 16          7          10           17             36            57
# 17          3           7           24             25            86
#
#    goals_balance points
# 0            +55     78
# 1            +28     65
# 2            +29     64
# 3            +24     61
# 4            +16     60
# 5            +14     52
# 6             +7     50
# 7             +8     49
# 8             +1     45
# 9              0     45
# 10            -2     43
# 11           -17     39
# 12           -18     36
# 13           -11     35
# 14           -26     35
# 15           -26     33
# 16           -21     31
# 17           -61     16

# %% [markdown]
# ## Join in one dataframe by year

# %% [markdown]
# For each standing file, we set the season id based on the file name to match the season id of the transfers file in case we need to cross data later.

# %%
standings_list = []

for file_name, df in standings_files.items():
    # set season id with the file name
    df['season_id'] = '20'+file_name[len(file_name)-5:len(file_name)-3]
    standings_list.append(df)

# concat all standings in a single dataframe
standings_df = pd.concat(standings_list, ignore_index=True)
print(standings_df.shape)
standings_df.head()
# Out:
# (90, 19)
#    final_standing                 team_name home_points home_wins home_draws  \
# 0               1             Bayern Munich          17        13          2
# 1               2         Borussia Dortmund          17        11          3
# 2               3                RB Leipzig          17         7          8
# 3               4  Borussia Mönchengladbach          17        12          2
# 4               5       Bayer 04 Leverkusen          17         9          4
#
#   home_losses away_points away_wins away_draws away_losses total_points  \
# 0           2          17        13          2           2           34
# 1           3          17        10          3           4           34
# 2           2          17        11          4           2           34
# 3           3          17         8          3           6           34
# 4           4          17        10          2           5           34
#
#   total_wins total_draws total_losses goals_in_favor goals_against  \
# 0         26           4            4            100            32
# 1         21           6            7             84            41
# 2         18          12            4             81            37
# 3         20           5            9             66            40
# 4         19           6            9             61            44
#
#   goals_balance points season_id
# 0           +68     82      2019
# 1           +43     69      2019
# 2           +44     66      2019
# 3           +26     65      2019
# 4           +17     63      2019

# %% [markdown]
# ## Set correct data types

# %%
standings_df.columns
# Out:
# Index(['final_standing', 'team_name', 'home_points', 'home_wins', 'home_draws',
#        'home_losses', 'away_points', 'away_wins', 'away_draws', 'away_losses',
#        'total_points', 'total_wins', 'total_draws', 'total_losses',
#        'goals_in_favor', 'goals_against', 'goals_balance', 'points',
#        'season_id'],
#       dtype='object')

# %%
# set numerical columns
numerical_cols = ['final_standing', 'home_points', 'home_wins', 'home_draws',
       'home_losses', 'away_points', 'away_wins', 'away_draws', 'away_losses',
       'total_points', 'total_wins', 'total_draws', 'total_losses',
       'goals_in_favor', 'goals_against', 'goals_balance', 'points']

# set categorical columns
cat_cols = ['team_name', 'season_id']

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Available seasons

# %%
print(f"Number of unique seasons: {standings_df['season_id'].nunique()}")
print(f"Available seasons: {standings_df['season_id'].unique()}")
# Out:
# Number of unique seasons: 5
# Available seasons: ['2019' '2021' '2023' '2022' '2020']

# %% [markdown]
# ### Teams per season

# %% [markdown]
# # Transfers

# %% [markdown]
# # EDA transfers
